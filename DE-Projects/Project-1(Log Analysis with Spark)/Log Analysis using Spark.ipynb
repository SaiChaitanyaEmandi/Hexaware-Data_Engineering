# %%
# creating a spark session

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Log_Analysis").getOrCreate()

# %%
# writing code to get the data from azure storage account into databricks

# %%
storage_account_name = "myproject1storage1055"
storage_account_key = "f6NTou9O4IHS84J8B2KF6R/M22p4fZZ/0kIJFhbwmgi4gawI3p1zM01w6+3A7xgHQ2CVHZAPxanz+AStJork3w=="
container = "mynewcontainer"

# %%
spark.conf.set(f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net", storage_account_key)

# %%
dbutils.fs.ls(f"wasbs://{container}@{storage_account_name}.blob.core.windows.net/")
# Out:
# [FileInfo(path='wasbs://mynewcontainer@myproject1storage1055.blob.core.windows.net/log_data.csv', name='log_data.csv', size=67110, modificationTime=1708837389000)]

# %%
# loading the data into dataframe

# %%
df = spark.read.csv(f"wasbs://{container}@{storage_account_name}.blob.core.windows.net/", header=True, inferSchema=True)

# %%
df.show(6)
# Out:
# +--------------------+---------------+--------------+-----------+----------+
# |           Timestamp|     IP Address|    User Agent|HTTP Status|Bytes Sent|
# +--------------------+---------------+--------------+-----------+----------+
# |2023-08-11 17:48:...| 192.168.165.48|UserAgent-5288|        404|      4447|
# |2023-09-15 03:49:...|192.168.156.225|UserAgent-6865|        404|      4975|
# |2023-04-06 19:26:...|192.168.137.242|UserAgent-8620|        404|      9168|
# |2023-10-26 16:08:...|192.168.116.143|UserAgent-8896|        200|      3665|
# |2024-01-27 08:56:...|192.168.233.122|UserAgent-9211|        200|      6421|
# |2023-08-23 17:32:...| 192.168.164.33|UserAgent-7927|        200|      9650|
# +--------------------+---------------+--------------+-----------+----------+
# only showing top 6 rows

# %%
# Instead of explicitly specifying the full path every time to access the data, we can use mounting

# %%
dbutils.fs.mount(
    source=f"wasbs://{container}@{storage_account_name}.blob.core.windows.net/",
    mount_point="/mnt/storage",
    extra_configs={f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net": storage_account_key}
)
# Out:
# True

# %%
dbutils.fs.mounts()
# Out:
# [MountInfo(mountPoint='/mnt/storage', source='wasbs://mynewcontainer@myproject1storage1055.blob.core.windows.net/', encryptionType=''),
#  MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType=''),
#  MountInfo(mountPoint='/Volumes', source='UnityCatalogVolumes', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType=''),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType=''),
#  MountInfo(mountPoint='/Volume', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/volumes', source='DbfsReserved', encryptionType=''),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType=''),
#  MountInfo(mountPoint='/volume', source='DbfsReserved', encryptionType='')]

# %%
df = spark.read.csv("/mnt/storage/log_data.csv", header=True, inferSchema=True)

# %%
df.show(7)
# Out:
# +--------------------+---------------+--------------+-----------+----------+
# |           Timestamp|     IP Address|    User Agent|HTTP Status|Bytes Sent|
# +--------------------+---------------+--------------+-----------+----------+
# |2023-08-11 17:48:...| 192.168.165.48|UserAgent-5288|        404|      4447|
# |2023-09-15 03:49:...|192.168.156.225|UserAgent-6865|        404|      4975|
# |2023-04-06 19:26:...|192.168.137.242|UserAgent-8620|        404|      9168|
# |2023-10-26 16:08:...|192.168.116.143|UserAgent-8896|        200|      3665|
# |2024-01-27 08:56:...|192.168.233.122|UserAgent-9211|        200|      6421|
# |2023-08-23 17:32:...| 192.168.164.33|UserAgent-7927|        200|      9650|
# |2023-05-22 15:25:...|   192.168.28.3|UserAgent-4801|        500|      1154|
# +--------------------+---------------+--------------+-----------+----------+
# only showing top 7 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Timestamp: timestamp (nullable = true)
#  |-- IP Address: string (nullable = true)
#  |-- User Agent: string (nullable = true)
#  |-- HTTP Status: integer (nullable = true)
#  |-- Bytes Sent: integer (nullable = true)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Timestamp</th><th>IP Address</th><th>User Agent</th><th>HTTP Status</th><th>Bytes Sent</th></tr></thead><tbody><tr><td>2023-08-11T17:48:25.348734Z</td><td>192.168.165.48</td><td>UserAgent-5288</td><td>404</td><td>4447</td></tr><tr><td>2023-09-15T03:49:34.348734Z</td><td>192.168.156.225</td><td>UserAgent-6865</td><td>404</td><td>4975</td></tr><tr><td>2023-04-06T19:26:37.348734Z</td><td>192.168.137.242</td><td>UserAgent-8620</td><td>404</td><td>9168</td></tr><tr><td>2023-10-26T16:08:19.348734Z</td><td>192.168.116.143</td><td>UserAgent-8896</td><td>200</td><td>3665</td></tr><tr><td>2024-01-27T08:56:08.348734Z</td><td>192.168.233.122</td><td>UserAgent-9211</td><td>200</td><td>6421</td></tr><tr><td>2023-08-23T17:32:56.348734Z</td><td>192.168.164.33</td><td>UserAgent-7927</td><td>200</td><td>9650</td></tr><tr><td>2023-05-22T15:25:44.348734Z</td><td>192.168.28.3</td><td>UserAgent-4801</td><td>500</td><td>1154</td></tr><tr><td>2023-09-11T21:38:44.348734Z</td><td>192.168.18.244</td><td>UserAgent-3672</td><td>404</td><td>4897</td></tr><tr><td>2023-10-11T07:21:07.348734Z</td><td>192.168.208.203</td><td>UserAgent-6127</td><td>200</td><td>8765</td></tr><tr><td>2023-05-08T05:54:30.348734Z</td><td>192.168.74.120</td><td>UserAgent-2420</td><td>500</td><td>3170</td></tr><tr><td>2023-10-01T22:27:21.348734Z</td><td>192.168.41.160</td><td>UserAgent-3817</td><td>500</td><td>5848</td></tr><tr><td>2023-11-03T21:05:22.348734Z</td><td>192.168.204.230</td><td>UserAgent-7966</td><td>200</td><td>2923</td></tr><tr><td>2023-02-24T10:28:17.348734Z</td><td>192.168.230.228</td><td>UserAgent-9619</td><td>200</td><td>795</td></tr><tr><td>2023-03-28T17:52:51.348734Z</td><td>192.168.183.157</td><td>UserAgent-7026</td><td>200</td><td>5327</td></tr><tr><td>2023-11-26T09:12:16.348734Z</td><td>192.168.133.160</td><td>UserAgent-6275</td><td>404</td><td>1939</td></tr><tr><td>2023-04-29T21:47:11.348734Z</td><td>192.168.195.130</td><td>UserAgent-3093</td><td>200</td><td>9079</td></tr><tr><td>2023-11-27T23:50:35.348734Z</td><td>192.168.64.121</td><td>UserAgent-6632</td><td>200</td><td>1181</td></tr><tr><td>2024-01-31T13:01:22.348734Z</td><td>192.168.75.194</td><td>UserAgent-9322</td><td>500</td><td>7055</td></tr><tr><td>2023-04-11T10:51:20.348734Z</td><td>192.168.13.211</td><td>UserAgent-6272</td><td>200</td><td>172</td></tr><tr><td>2023-12-22T18:48:57.348734Z</td><td>192.168.179.141</td><td>UserAgent-8420</td><td>404</td><td>6236</td></tr><tr><td>2023-10-15T22:27:13.348734Z</td><td>192.168.85.253</td><td>UserAgent-4589</td><td>500</td><td>1141</td></tr><tr><td>2023-09-25T16:56:48.348734Z</td><td>192.168.97.92</td><td>UserAgent-1972</td><td>404</td><td>2193</td></tr><tr><td>2023-08-09T23:49:17.348734Z</td><td>192.168.37.103</td><td>UserAgent-7412</td><td>200</td><td>4698</td></tr><tr><td>2023-11-16T10:23:31.348734Z</td><td>192.168.39.78</td><td>UserAgent-8301</td><td>500</td><td>9363</td></tr><tr><td>2024-02-17T14:29:59.348734Z</td><td>192.168.69.96</td><td>UserAgent-3348</td><td>404</td><td>7445</td></tr><tr><td>2023-03-25T10:32:11.348734Z</td><td>192.168.134.225</td><td>UserAgent-8828</td><td>200</td><td>7633</td></tr><tr><td>2023-02-24T14:42:24.348734Z</td><td>192.168.29.163</td><td>UserAgent-3611</td><td>200</td><td>7191</td></tr><tr><td>2023-04-25T19:00:28.348734Z</td><td>192.168.19.146</td><td>UserAgent-2168</td><td>200</td><td>9267</td></tr><tr><td>2023-03-25T17:40:08.348734Z</td><td>192.168.89.215</td><td>UserAgent-9637</td><td>404</td><td>2583</td></tr><tr><td>2023-04-26T21:27:51.348734Z</td><td>192.168.251.188</td><td>UserAgent-1541</td><td>500</td><td>3506</td></tr><tr><td>2023-08-15T14:37:53.348734Z</td><td>192.168.230.56</td><td>UserAgent-7180</td><td>404</td><td>6343</td></tr><tr><td>2023-12-23T23:55:51.348734Z</td><td>192.168.120.244</td><td>UserAgent-8449</td><td>404</td><td>4076</td></tr><tr><td>2024-01-16T00:51:58.348734Z</td><td>192.168 ...
# Databricks visualization. Run in Databricks to view.

# %%
# Handling missing values

# %%
df = df.na.drop()

# %%
# Let's compute basic statistics for numerical columns

# %%
df.describe().show()
# Out:
# +-------+-------------+--------------+------------------+------------------+
# |summary|   IP Address|    User Agent|       HTTP Status|        Bytes Sent|
# +-------+-------------+--------------+------------------+------------------+
# |  count|         1000|          1000|              1000|              1000|
# |   mean|         NULL|          NULL|           361.244|          5044.013|
# | stddev|         NULL|          NULL|123.77022069759556|2899.8028483657986|
# |    min|192.168.0.175|UserAgent-1005|               200|               108|
# |    max| 192.168.99.6|UserAgent-9991|               500|              9999|
# +-------+-------------+--------------+------------------+------------------+

# %%
# Finding error rates

# %%
total_records = df.count()

# %%
from pyspark.sql.functions import col
error_records = df.filter((col('HTTP Status') == 404) | (col('HTTP Status') == 500)).count()

# %%
error_rate = (error_records / total_records) * 100
error_rate
# Out:
# 65.3

# %%
# Analyzing trends
# We can analyze trends by grouping data by a certain time interval

# %%
trends = df.groupBy(df.Timestamp.cast("date").alias("Date"), "HTTP Status").count().orderBy("Date")

# %%
# Trend of HTTP Status over time
trends.show()
# Out:
# +----------+-----------+-----+
# |      Date|HTTP Status|count|
# +----------+-----------+-----+
# |2023-02-24|        200|    3|
# |2023-02-24|        500|    1|
# |2023-02-24|        404|    2|
# |2023-02-25|        200|    1|
# |2023-02-25|        500|    1|
# |2023-02-26|        200|    1|
# |2023-02-26|        500|    1|
# |2023-02-27|        200|    1|
# |2023-02-28|        200|    1|
# |2023-03-01|        500|    1|
# |2023-03-02|        200|    1|
# |2023-03-03|        404|    1|
# |2023-03-03|        200|    1|
# |2023-03-04|        200|    1|
# |2023-03-05|        500|    1|
# |2023-03-05|        404|    1|
# |2023-03-06|        500|    1|
# |2023-03-06|        404|    1|
# |2023-03-06|        200|    1|
# |2023-03-07|        404|    3|
# +----------+-----------+-----+
# only showing top 20 rows

# %%
ip_trends = df.groupBy(df.Timestamp.cast("date").alias("Date"), "IP Address").count().orderBy("Date")

# %%
# Trend of Requests from IP Addresses over Time
ip_trends.show()
# Out:
# +----------+---------------+-----+
# |      Date|     IP Address|count|
# +----------+---------------+-----+
# |2023-02-24| 192.168.29.163|    1|
# |2023-02-24| 192.168.231.10|    1|
# |2023-02-24|192.168.230.228|    1|
# |2023-02-24|192.168.252.251|    1|
# |2023-02-24|  192.168.46.90|    1|
# |2023-02-24|192.168.181.238|    1|
# |2023-02-25| 192.168.167.73|    1|
# |2023-02-25|  192.168.13.73|    1|
# |2023-02-26| 192.168.76.213|    1|
# |2023-02-26| 192.168.161.72|    1|
# |2023-02-27|  192.168.94.65|    1|
# |2023-02-28|192.168.201.229|    1|
# |2023-03-01|192.168.171.228|    1|
# |2023-03-02| 192.168.162.18|    1|
# |2023-03-03| 192.168.66.147|    1|
# |2023-03-03|   192.168.13.2|    1|
# |2023-03-04| 192.168.88.211|    1|
# |2023-03-05|  192.168.227.9|    1|
# |2023-03-05| 192.168.133.61|    1|
# |2023-03-06|  192.168.38.78|    1|
# +----------+---------------+-----+
# only showing top 20 rows
